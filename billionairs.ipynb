# %%
import wingdbstub
wingdbstub.Ensure()

# %%
import importlib
import billionair_fetch as bf
if True:
    driver=bf.proff_login()
else:
    driver=None
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST driver version for 97.0.4692
# Driver [C:\Users\esi000\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache

# %%
from billionair_fetch import *
tbl='OID_400'
conn,crsr=DB.Connect(db)
DB.createTable(tbl,conn,crsr,droptable=True)
columns=f"[{('], ['.join(DB.GetColumnNames(crsr,tbl)[0][1:]))}]"
sqlstr=DB.GetSQLInsertStr(tbl,columns)
namelist=list(pd.read_csv('names.csv',encoding='ANSI',names=['Names']).iloc[:,0])

# %%
importlib.reload(bf)
k=0
for name in namelist:
    if (k>=0):# and (orgid in [811176702]):
        print ( 'Appending %s ' %(name,),)
        bf.AppendData(name,conn,crsr,sqlstr,driver)
        print ( ' done')
    k+=1
# Out:
# Appending John Fredriksen
#  done
# Appending Ole Andreas Halvorsen
#  done
# Appending Odd Reitan
# Adding ODD REITAN PRIVATE HOLDING AS(Odd Reitan)
# Adding REITAN AS(Odd Reitan)
# Adding FOA AS(Odd Reitan)
# Adding NYE HJORTEN TEATER AS(Odd Reitan)
# Adding REITAN RETAIL AS(Odd Reitan)
# Adding REMA 1000 AS(Odd Reitan)
# Adding LOSBY GOLFPARK AS(Odd Reitan)
# Adding REITAN HANDEL AS(Odd Reitan)
# Adding GLADENGEN DRIFT AS(Odd Reitan)
# Adding REITAN CONVENIENCE AS(Odd Reitan)
# Adding REITAN CONVENIENCE NORWAY AS(Odd Reitan)
# Adding BYTERMINALEN AS(Odd Reitan)
# Adding ASKER SENTRUM AS(Odd Reitan)
# Adding HAUGESUND SENTRUM NÆRINGSDRIFT AS(Odd Reitan)
# Adding REITAN KAPITAL AS(Odd Reitan)
# Adding PROVENTURE SEED III AS(Odd Reitan)
# Adding CIMON MEDICAL AS(Odd Reitan)
# Adding GLOBAL STORAGE SOLUTIONS AS(Odd Reitan)
# Adding POSTEN MODERNE AS(Odd Reitan)
# Adding RK REORGANISERING AS(Odd Reitan)
# Adding GRENOR AS(Odd Reitan)
# Adding PAPAGAYO ENERGY AS(Odd Reitan)
# Adding GRENOR KAMERUN AS(Odd Reitan)
# Adding AVANTAS AS(Odd Reitan)
# Adding AVANTAS DRIFT AS(Odd Reitan)
# Adding BRITANNIA HOTEL AS(Odd Reitan)
# Adding RELY AS(Odd Reitan)
# Adding REITAN HOLDING AS(Odd Reitan)
# Adding UNO-X MOBILITY AS(Odd Reitan)
# Adding YX NORGE AS(Odd Reitan)
# Adding GASOLIN RUDSHØGDA AS(Odd Reitan)
# Adding YX SMØREOLJE AS(Odd Reitan)
# Adding UNO-X NORGE AS(Odd Reitan)
# Adding UNO-X SYKKEL AS(Odd Reitan)
# Adding FIRSTCYCLING AS(Odd Reitan)
# Adding LURA EIENDOM AS(Odd Reitan)
# Adding MADLAVEIEN 77 AS(Odd Reitan)
# Adding UNO-X E-MOBILITY NORGE AS(Odd Reitan)
# Adding UNO-X FORSYNING AS(Odd Reitan)
# Adding H2CO AS(Odd Reitan)
# Adding REITAN EIENDOM AS(Odd Reitan)
# Adding PRO STAV AS(Odd Reitan)
# Adding KASTBREKKA EIENDOM AS(Odd Reitan)
# Adding D1A UTVIKLING AS(Odd Reitan)
# Adding RCL EIENDOM AS(Odd Reitan)
# Adding REN RISVOLLAN AS(Odd Reitan)
# Adding YX EIENDOM LEANGEN AS(Odd Reitan)
# Adding ROSE INVEST AS(Odd Reitan)
# Adding KORTEN UTVIKLING AS(Odd Reitan)
# Adding NHP SØR AS(Odd Reitan)
# Adding ENGER UTVIKLING AS(Odd Reitan)
# Adding RINGDALSKOGEN AS(Odd Reitan)
# Adding PASA ENGER AS(Odd Reitan)
# Adding DANEBO UTVIKLING AS(Odd Reitan)
# Adding DRAUPNER INVESTERINGER AS(Odd Reitan)
# Adding LØRENSKOG BUTIKKEIENDOM AS(Odd Reitan)
# Adding JESSHEIM SØR NÆRING AS(Odd Reitan)
# Adding RELI MYRENE AS(Odd Reitan)
# Adding BROKK NÆRINGSEIENDOM AS(Odd Reitan)
# Adding ØSTEBØMYR ENERGI AS(Odd Reitan)
# Adding ØSTEBØMYR EIENDOM AS(Odd Reitan)
# Adding RISØRSENTERET AS(Odd Reitan)
# Adding RELI SKIEN AS(Odd Reitan)
# Adding RISØRTAKET BOLIG AS(Odd Reitan)
# Adding BULGARIA EIENDOM INVEST AS(Odd Reitan)
# Adding REITAN TVETERAAS AS(Odd Reitan)
# Adding AMER EIENDOM AS(Odd Reitan)
# Adding GANDDAL NÆRINGSPARK AS(Odd Reitan)
# Adding BUTIKKEIENDOM SKJÆVELAND AS(Odd Reitan)
# Adding YX KROODDEN EIENDOM AS(Odd Reitan)
# Adding BEGG EIENDOM AS(Odd Reitan)
# Adding REAL ESTATE CENTRAL EUROPE AS(Odd Reitan)
# Adding RELOG DRIFT AS(Odd Reitan)
# Adding VON KROGH INVEST AS(Odd Reitan)
# Adding DALGÅRD BOLIG AS(Odd Reitan)
# Adding DORA HOLDING AS(Odd Reitan)
# Adding JARLHEIMSLETTA AS(Odd Reitan)
# Adding LADE TEKNOPARK AS(Odd Reitan)
# Adding STRANDVEIUTSIKTEN AS(Odd Reitan)
# Adding NYE GRANÅSEN EIENDOM AS(Odd Reitan)
# Adding TRESS UTVIKLING AS(Odd Reitan)
# Adding DALGÅRD UTVIKLING AS(Odd Reitan)
# Adding Bachke & Co. A/S(Odd Reitan)
# Adding AQUASTRUCTURES AS(Odd Reitan)
# Adding LILLEHAMMER PANORAMA I AS(Odd Reitan)
# Adding NORDVEST LAGERHOTELL AS(Odd Reitan)
# Adding KVERNBERGET VEKST AS(Odd Reitan)
# Adding BEWI ASA(Odd Reitan)
# Adding WALLENIUS WILHELMSEN ASA(Odd Reitan)
# Adding YARA INTERNATIONAL ASA(Odd Reitan)
# Adding TGS ASA(Odd Reitan)
# Adding ORKLA ASA(Odd Reitan)
# Adding LOFOTEN MARINE OILS AS(Odd Reitan)
# Adding ORKLA HEALTH AS(Odd Reitan)
# Adding PROTEINFABRIKKEN AS(Odd Reitan)
# Adding TROUX HOLDING AS(Odd Reitan)
# Adding SARSIA DEVELOPMENT AS(Odd Reitan)
# Adding EPSIS AS(Odd Reitan)
# Adding PRODUCTION MONITORING AS(Odd Reitan)
# Adding SARSIA SEED AS(Odd Reitan)
# Adding AQUILOZ AS(Odd Reitan)
# Adding APIM THERAPEUTICS AS(Odd Reitan)
# Adding WINDSIM AS(Odd Reitan)
# Adding SEAFARM SOLUTIONS AS(Odd Reitan)
# Adding SEA-HAWK NAVIGATION AS(Odd Reitan)
# Adding SORBWATER TECHNOLOGY AS(Odd Reitan)
# Adding PROPHYLIX PHARMA HOLDING AS(Odd Reitan)
# Adding PROPHYLIX AS(Odd Reitan)
# Adding MED STORM INNOVATION AS(Odd Reitan)
# Adding DEEPX HEALTH AS(Odd Reitan)
# Adding SCREENCANCER AS(Odd Reitan)
# Adding DEEPX ANALYTICS AS(Odd Reitan)
# Adding BALTER MEDICAL AS(Odd Reitan)
# Adding BERGENBIO ASA(Odd Reitan)
# Adding NYKODE THERAPEUTICS AS(Odd Reitan)
# Adding Norsk Hydro ASA(Odd Reitan)
# Adding DATAKORTET AS(Odd Reitan)
# Adding ORINOR AS(Odd Reitan)
# Adding FINNMARKSKONFERANSEN AS(Odd Reitan)
# Adding NORDKAPPREGIONEN NÆRINGSHAGE AS(Odd Reitan)
# Adding TIVOLI NORTH AS(Odd Reitan)
# Adding AVJU SOLUTIONS AS(Odd Reitan)
# Adding OSLOTECH AS(Odd Reitan)
# Adding ALEAP AS(Odd Reitan)
# Adding ARISTEIA AS(Odd Reitan)
# Adding BIO-ME AS(Odd Reitan)
# Adding PACERTOOL AS(Odd Reitan)
# Adding CARDINOR AS(Odd Reitan)
# Adding INDEPENDENCE GEAR AS(Odd Reitan)
# Adding AGE LABS AS(Odd Reitan)
# Adding OIVI AS(Odd Reitan)
# Adding ROCKET ASSET MANAGEMENT AS(Odd Reitan)
# Adding FOUNDERS FUND II AS(Odd Reitan)
# Adding SMART CYLINDERS AS(Odd Reitan)
# Adding AXEPTIA CREDIT INTELLIGENCE AS(Odd Reitan)
# Adding INTELECY AS(Odd Reitan)
# Adding EDINSIGHTS AS(Odd Reitan)
# Adding GLOBUS HOLDING AS(Odd Reitan)
# Adding GREPS AS(Odd Reitan)
# Adding PLAATO TECHNOLOGIES AS(Odd Reitan)
# Adding SCRIMBA HOLDING AS(Odd Reitan)
# Adding SENSIBEL AS(Odd Reitan)
# Adding LUCIDTECH AS(Odd Reitan)
# Adding CONFRERE AS(Odd Reitan)
# Adding CAKE IT EASY AS(Odd Reitan)
# Adding TUNABLE AS(Odd Reitan)
# Adding FUNDINGPARTNER AS(Odd Reitan)
# Adding FUNDINGPARTNER GROUP AS(Odd Reitan)
# Adding FUNDINGPARTNER SECURITIES AS(Odd Reitan)
# Adding HOLD AS(Odd Reitan)
# Adding PLAYFINITY AS(Odd Reitan)
# Adding PLAYFINITY NORGE AS(Odd Reitan)
# Adding DIFFIA AS(Odd Reitan)
# Adding STARTUPLAB AS(Odd Reitan)
# Adding DOMOS AS(Odd Reitan)
# Adding 6AM ACCELERATOR AS(Odd Reitan)
# Adding MOJOB NORGE AS(Odd Reitan)
# Adding BAGID AS(Odd Reitan)
# Adding ANTEO AS(Odd Reitan)
# Adding ORIVO AS(Odd Reitan)
# Adding CLUB UNITED AS(Odd Reitan)
# Adding SUPEREGO AS(Odd Reitan)
# Adding QRRNT AS(Odd Reitan)
# Adding HEADSHED AS(Odd Reitan)
# Adding XERIS AS(Odd Reitan)
# Adding WAY AS(Odd Reitan)
# Adding MEMOSCALE AS(Odd Reitan)
# Adding UBIQ AEROSPACE AS(Odd Reitan)
# Adding BLUEYE ROBOTICS AS(Odd Reitan)
# Adding LISTEN AS(Odd Reitan)
# Adding NORWEGIAN BLUE AS(Odd Reitan)
# Adding SKIWO AS(Odd Reitan)
# Adding REMARKABLE HOLDING AS(Odd Reitan)
# Adding REMARKABLE AS(Odd Reitan)
# Adding REMARKABLE EMPLOYEE SHARE HOLDING I AS(Odd Reitan)
# Adding JOYMO AS(Odd Reitan)
# Adding NO ISOLATION AS(Odd Reitan)
# Adding SPIFF AS(Odd Reitan)
# Adding OSLO SCIENCE PARK AS(Odd Reitan)
# Adding CIENS EIENDOM AS(Odd Reitan)
# Adding FOUNDERS FUND I AS(Odd Reitan)
# Adding ANTAGONIST AS(Odd Reitan)
# Adding TURNING DATA INTO PRODUCTS AS(Odd Reitan)
# Adding SOCIALBOARDS AS(Odd Reitan)
# Adding NORTHERN.TECH HOLDING AS(Odd Reitan)
# Adding NORTHERN.TECH AS(Odd Reitan)
# Adding VIVA LABS AS(Odd Reitan)
# Adding DRYLAB R & D AS(Odd Reitan)
# Adding HARVEST FUNDS AS(Odd Reitan)
# Adding HARVEST OMEGA DTR AS(Odd Reitan)
# Adding OSLO SCIENCE PARK III AS(Odd Reitan)
# Adding OSLO KONTOREIENDOM II HOLDING AS(Odd Reitan)
# Adding FORSKNINGSPARKEN HUS 5 AS(Odd Reitan)
# Adding FORSKNINGSPARKEN ENERGI AS(Odd Reitan)
# Adding VISTECHNOLOGIES AS(Odd Reitan)
# Adding OSLO SCIENCE PARK II AS(Odd Reitan)
# Adding OSLO KONTOREIENDOM I AS(Odd Reitan)
# Adding GAUSTADALLEEN 21 KOMPLEMENTAR AS(Odd Reitan)
# Adding GAUSTADALLEEN 21 HJEMMEL AS(Odd Reitan)
# Adding GAUSTADALLEN 21 AS(Odd Reitan)
# Adding STARTUPLAB FOUNDERS AS(Odd Reitan)
# Adding CLERIA AS(Odd Reitan)
# Adding YG TECHNOLOGIES AS(Odd Reitan)
# Adding KVIKSTEP AS(Odd Reitan)
# Adding TEMPOGENE AS(Odd Reitan)
# Adding GADUS GENETICS AS(Odd Reitan)
# Adding HECATEX AS(Odd Reitan)
# Adding COMPAX SOLUTIONS AS(Odd Reitan)
# Adding COMPAX NEXT AS(Odd Reitan)
# Adding CUBIT AS(Odd Reitan)
# Adding SEAFOOD7 AS(Odd Reitan)
# Adding BRANDPAD AS(Odd Reitan)
# Adding AIVERO AS(Odd Reitan)
# Adding ACCOUNTFLOW AS(Odd Reitan)
# Adding S:MART AS(Odd Reitan)
# Adding DISRUPTIVE ENGINEERING AS(Odd Reitan)
# Adding FOODSOFT AS(Odd Reitan)
# Adding MINUENDO AS(Odd Reitan)
# Adding MAINDECK AS(Odd Reitan)
# Adding SOLGT.NO AS(Odd Reitan)
# Adding NOMONO AS(Odd Reitan)
# Adding ORDR AS(Odd Reitan)
# Adding WIRAL TECHNOLOGIES AS(Odd Reitan)
# Adding FILMGRAIL AS(Odd Reitan)
# Adding SPERMATECH AS(Odd Reitan)
# Adding AIMS INNOVATION HOLDING AS(Odd Reitan)
# Adding AIMS INNOVATION AS(Odd Reitan)
# Adding ALLIANCE VENTURE SPRING AS(Odd Reitan)
# Adding SHORELINE AS(Odd Reitan)
# Adding FUSETOOLS AS(Odd Reitan)
# Adding XENETA AS(Odd Reitan)
# Adding GRUNT AS(Odd Reitan)
# Adding BOOST AI AS(Odd Reitan)
# Adding SANITY HOLDING AS(Odd Reitan)
# Adding APRILA BANK ASA(Odd Reitan)
# Adding SWARM64 AS(Odd Reitan)
# Adding EVENTUM NORGE AS(Odd Reitan)
# Adding ODA NORWAY AS(Odd Reitan)
# Adding KORN BAKERI AS(Odd Reitan)
# Adding KOLONIAL.NO DISTRIBUSJON AS(Odd Reitan)
# Adding ODA GROUP HOLDING AS(Odd Reitan)
# Adding ODA GROUP SERVICES AS(Odd Reitan)
# Adding NETFRESH AS(Odd Reitan)
# Adding BIOMOLEX AS(Odd Reitan)
# Adding NEXTERA AS(Odd Reitan)
# Adding DNB ASA(Odd Reitan)
# Adding FREMTIND FORSIKRING AS(Odd Reitan)
# Adding DNB SCANDINAVIAN PROPFUND HM AS(Odd Reitan)
# Adding MOLDE SENTRUM AS(Odd Reitan)
# Adding ARCUS ASA(Odd Reitan)
# Adding ARCUS HOLDING AS(Odd Reitan)
# Adding ARCUS-GRUPPEN AS(Odd Reitan)
# Adding ARCUS NORWAY AS(Odd Reitan)
# Adding ATLUNGSTAD BRENNERI AS(Odd Reitan)
# Adding VINGRUPPEN AS(Odd Reitan)
# Adding VINUNIQ AS(Odd Reitan)
# Adding EXCELLARS AS(Odd Reitan)
# Adding ARCUS WINE BRANDS AS(Odd Reitan)
# Adding ARCUS CO BRANDS AS(Odd Reitan)
# Adding ARCUS BRAND LAB AS(Odd Reitan)
# Adding CLASSIC WINES AS(Odd Reitan)
# Adding CREATIVE WINES AS(Odd Reitan)
# Adding VINORDIA AS(Odd Reitan)
# Adding HEYDAY WINES AS(Odd Reitan)
# Adding SYMPOSIUM WINES AS(Odd Reitan)
# Adding HEDONI WINES AS(Odd Reitan)
# Adding WONGRAVEN WINES AS(Odd Reitan)
# Adding VECTURA AS(Odd Reitan)
# Adding VINIFY AS(Odd Reitan)
# Adding BEVERAGE LINK AS(Odd Reitan)
# Adding Veidekke ASA(Odd Reitan)
# Adding SKULEGARD AS(Odd Reitan)
# Adding STAMVEG AS(Odd Reitan)
# Adding SKULEPLASS AS(Odd Reitan)
# Adding SKULEBYGG AS(Odd Reitan)
# Adding SKULEBYGG FESTER AS(Odd Reitan)
# Adding SKULEVEG AS(Odd Reitan)
# Adding ALLFARVEG AS(Odd Reitan)
# Adding KNARREVIK-SOTRA BYGGESELSKAP AS(Odd Reitan)
# Adding VÅGE TOMTESELSKAP AS(Odd Reitan)
# Adding NORDIC SEMICONDUCTOR ASA(Odd Reitan)
# Adding ATEA ASA(Odd Reitan)
# Adding KONGSBERG GRUPPEN ASA(Odd Reitan)
# Adding NAVIA INVEST AS(Odd Reitan)
# Adding KONGSBERG DIGITAL AS(Odd Reitan)
# Adding KONCIV AS(Odd Reitan)
# Adding ESMART SYSTEMS AS(Odd Reitan)
# Adding RAVEN AS(Odd Reitan)
# Adding SMART COGNITION AS(Odd Reitan)
# Adding NORDIC MEDIA LAB AS(Odd Reitan)
# Adding V.A.D AS(Odd Reitan)
# Adding ASKERSHUS AS(Odd Reitan)
# Adding HALLINGDAL NÆRINGSHAGE AS(Odd Reitan)
# Adding DBC SENTERET AS(Odd Reitan)
# Adding GORDARIKE AS(Odd Reitan)
# Adding KONGSBERG INNOVASJON AS(Odd Reitan)
# Adding DISTRIBUTED SHIP SURVEILLANCE AS(Odd Reitan)
# Adding PROFMOF AS(Odd Reitan)
# Adding X-TR AS(Odd Reitan)
# Adding KONGSBERG FERROTECH AS(Odd Reitan)
# Adding VASSHELLA FLEXIBLES AS(Odd Reitan)
# Adding KYOTO GROUP AS(Odd Reitan)
# Adding SUNTRAP AS(Odd Reitan)
# Adding BUTTERFLY MANUFACTURING AS(Odd Reitan)
# Adding DIMEQ AS(Odd Reitan)
# Adding BRUDELI GREEN MOBILITY AS(Odd Reitan)
# Adding KITEMILL AS(Odd Reitan)
# Adding POWUNIT AS(Odd Reitan)
# Adding FUNZIONANO AS(Odd Reitan)
# Adding SCALE PROTECTION AS(Odd Reitan)
# Adding SCALE MANAGEMENT AS(Odd Reitan)
# Adding KONGSBERG BEAM TECHNOLOGY AS(Odd Reitan)
# Adding N2 APPLIED AS(Odd Reitan)
# Adding N2 INDUSTRIAL AS(Odd Reitan)
# Adding N2 AGRI AS(Odd Reitan)
# Adding TOPPINDUSTRISENTERET AS(Odd Reitan)
# Adding PROVENTURE SEED AS(Odd Reitan)
# Adding CONOPTICA AS(Odd Reitan)
# Adding NUMASCALE AS(Odd Reitan)
# Adding CUPP COMPUTING AS(Odd Reitan)
# Adding NORINNOVA INVEST AS(Odd Reitan)
# Adding DUALOG AS(Odd Reitan)
# Adding RESIGHT AS(Odd Reitan)
# Adding CALANUS AS(Odd Reitan)
# Adding SALGARD AS(Odd Reitan)
# Adding CALANUS HELSE AS(Odd Reitan)
# Adding CALANUS EIENDOM AS(Odd Reitan)
# Adding VITUX GROUP AS(Odd Reitan)
# Adding VITUX PHARMA AS(Odd Reitan)
# Adding VITUX AS(Odd Reitan)
# Adding LYFSTONE AS(Odd Reitan)
# Adding LYFSTONE INVEST AS(Odd Reitan)
# Adding LYTIX BIOPHARMA AS(Odd Reitan)
# Adding AMICOAT AS(Odd Reitan)
# Adding PEPTIDE PATENTS AS(Odd Reitan)
# Adding PHARMASUM THERAPEUTICS AS(Odd Reitan)
# Adding PHARMA HOLDINGS AS(Odd Reitan)
# Adding LEIV EIRIKSSON NYSKAPING AS(Odd Reitan)
# Adding MORE INNOVATION AS(Odd Reitan)
# Adding TJELDBERGODDEN RENSEFISK AS(Odd Reitan)
# Adding VECTRON BIOSOLUTIONS AS(Odd Reitan)
# Adding FIELDBUS INTERNATIONAL AS(Odd Reitan)
# Adding COMEX AS(Odd Reitan)
# Adding BYKS AS(Odd Reitan)
# Adding HOOPLA AS(Odd Reitan)
# Adding HOOPLA ADVERTISING AS(Odd Reitan)
# Adding GIVN HOLDING AS(Odd Reitan)
# Adding GIVN NORGE AS(Odd Reitan)
# Adding FIIZK HOLDING AS(Odd Reitan)
# Adding FIIZK PROTECTION AS(Odd Reitan)
# Adding FIIZK CLOSED SYSTEMS AS(Odd Reitan)
# Adding FIIZK COVERS AS(Odd Reitan)
# Adding FIIZK DIGITAL AS(Odd Reitan)
# Adding FIIZK GROUP AS(Odd Reitan)
# Adding FIIZK DIGITAL SOLUTIONS AS(Odd Reitan)
# Adding FIIZK DIGITAL INTEGRATOR AS(Odd Reitan)
# Adding FIIZK DIGITAL CTRL AS(Odd Reitan)
# Adding HYDRIGO AS(Odd Reitan)
# Adding ADTUBE AS(Odd Reitan)
# Adding OCEAN ENERGY AS(Odd Reitan)
# Adding NORTH RESOURCES AS(Odd Reitan)
# Adding SOLSTAD OFFSHORE ASA(Odd Reitan)
# Adding ÅKP AS(Odd Reitan)
# Adding URBAN GARTNEREN AS(Odd Reitan)
# Adding ROM & TONIK AS(Odd Reitan)
# Adding INZPERO AS(Odd Reitan)
# Adding CREATEVIEW AS(Odd Reitan)
# Adding NORDVEGGEN AS(Odd Reitan)
# Adding TANGO SEAWEED AS(Odd Reitan)
# Adding TANGO SEAWEED EIENDOM AS(Odd Reitan)
# Adding EFFEE INDUCTION AS(Odd Reitan)
# Adding EFFEE AS(Odd Reitan)
# Adding ZEGEBA AS(Odd Reitan)
# Adding HAREID FASTLANDSAMBAND AS(Odd Reitan)
# Adding REINS KLOSTER AS(Odd Reitan)
# Adding BULBITECH AS(Odd Reitan)
# Adding POLYDISPLAY AS(Odd Reitan)
# Adding MICROTECH INNOVATION AS(Odd Reitan)
# Adding SENSOCURE AS(Odd Reitan)
# Adding MTI STARTUP AS(Odd Reitan)
# Adding CLIKK AS(Odd Reitan)
# Adding WIONETIC AS(Odd Reitan)
# Adding OCEANTHERM AS(Odd Reitan)
# Adding BRIDGEHILL AS(Odd Reitan)
# Adding WITTARIO AS(Odd Reitan)
# Adding INSINT AS(Odd Reitan)
# Adding ANGEL CHALLENGE SYNDICATE OIZOM AS(Odd Reitan)
# Adding WAI ENVIRONMENTAL SOLUTIONS AS(Odd Reitan)
# Adding OTTEM CARBONWORKS AS(Odd Reitan)
# Adding SMARTGROUP AS(Odd Reitan)
# Adding LIPIT SOLUTIONS AS(Odd Reitan)
# Adding SMARTMOVE AS(Odd Reitan)
# Adding VITIR AS(Odd Reitan)
# Adding SPORTS COMPUTING AS(Odd Reitan)
# Adding OSMOLIFE AS(Odd Reitan)
# Adding LIFECARE AS(Odd Reitan)
# Adding SPAREBANK 1 SR-BANK ASA(Odd Reitan)
# Adding BN BANK ASA(Odd Reitan)
# Adding SPAREBANK 1 BOLIGKREDITT AS(Odd Reitan)
# Adding BANKENES ID-TJENESTE AS(Odd Reitan)
# Adding SPAREBANK 1 GJELDSINFORMASJON AS(Odd Reitan)
# Adding NORSK GJELDSINFORMASJON AS(Odd Reitan)
# Adding SPAREBANK 1 KREDITT AS(Odd Reitan)
# Adding SPAREBANK 1 BETALING AS(Odd Reitan)
# Adding VIPPS AS(Odd Reitan)
# Adding BANKAXEPT AS(Odd Reitan)
# Adding NORDIC FUTURE INNOVATION AS(Odd Reitan)
# Adding BANKID NORGE AS(Odd Reitan)
# Adding VIPPS MOBIL AS(Odd Reitan)
# Adding VIPPS ID SOLUTIONS AS(Odd Reitan)
# Adding VIPPS TEKNOLOGI AS(Odd Reitan)
# Adding VBB AS(Odd Reitan)
# Adding VIPPS INTERNATIONAL AS(Odd Reitan)
# Adding SETTLE GROUP AS(Odd Reitan)
# Adding NORDIC HALIBUT AS(Odd Reitan)
# Adding BERGEN SENTRUM TOMTESELSKAP AS(Odd Reitan)
# Adding NORDIC EDGE AS(Odd Reitan)
# Adding SPAREBANK 1 BANK OG REGNSKAP AS(Odd Reitan)
# Adding B&R HOLDING AS(Odd Reitan)
# Adding VALIDÉ INVEST I AS(Odd Reitan)
# Adding CENTRAFLOW AS(Odd Reitan)
# Adding PALEBLUE AS(Odd Reitan)
# Adding FOODBACK AS(Odd Reitan)
# Adding ECOFIBER RECYCLING AS(Odd Reitan)
# Adding SMART CROWDING AS(Odd Reitan)
# Adding ANIPORT AS(Odd Reitan)
# Adding TERP AS(Odd Reitan)
# Adding ADLEARE AS(Odd Reitan)
# Adding INFOGYM AS(Odd Reitan)
# Adding EXEDRA AS(Odd Reitan)
# Adding SAFEROCK AS(Odd Reitan)
# Adding ALGINOR ASA(Odd Reitan)
# Adding ALGINOR INDUSTRIAL ESTATE AS(Odd Reitan)
# Adding HYPOMAR AS(Odd Reitan)
# Adding OEWA AS(Odd Reitan)
# Adding ALGINOR BIOREFINERY AS(Odd Reitan)
# Adding ALGINOR PHARMA INGREDIENTS AS(Odd Reitan)
# Adding QWAVE AS(Odd Reitan)
# Adding SPAREBANK 1 GRUPPEN AS(Odd Reitan)
# Adding LOFAVØR AS(Odd Reitan)
# Adding EIENDOMSVERDI AS(Odd Reitan)
# Adding PNGR AS(Odd Reitan)
# Adding NORDIC CREDIT RATING AS(Odd Reitan)
# Adding SPAREBANK 1 NÆRINGSKREDITT AS(Odd Reitan)
# Adding SPAMA AS(Odd Reitan)
# Adding SEM & STENERSEN PROKOM AS(Odd Reitan)
# Adding REISEMÅL RYFYLKE AS(Odd Reitan)
# Adding FJORD NORGE AS(Odd Reitan)
# Adding VARDE OPPLEVELSESKVALITET AS(Odd Reitan)
# Adding SPAREBANK 1 MARKETS AS(Odd Reitan)
# Adding INSR INSURANCE GROUP ASA(Odd Reitan)
# Adding HT GROUP AS(Odd Reitan)
# Adding TRIBE VENNEFORSIKRING AS(Odd Reitan)
# Adding INTELLITECH AS(Odd Reitan)
# Adding ITERA ASA(Odd Reitan)
# Adding ENDÚR ASA(Odd Reitan)
# Adding KUPA AS(Odd Reitan)
# Adding PREECAP AS(Odd Reitan)
# Adding MEDSENSIO AS(Odd Reitan)
# Adding SENTRUM NÆRINGSHAGE AS(Odd Reitan)
# Adding BRØNNØY FISKEMOTTAK AS(Odd Reitan)
# Adding TOROLVSTEIN AS(Odd Reitan)
# Adding SANDNESSJØEN EVENT AS(Odd Reitan)
# Adding SJØMATKLYNGEN SENJA AS(Odd Reitan)
# Adding NORSKIN MATERIALS AS(Odd Reitan)
# Adding NORSKIN AS(Odd Reitan)
# Adding PROBOTIC AS(Odd Reitan)
# Adding VISIT HARSTAD AS(Odd Reitan)
# Adding ARCTICONCEPTS AS(Odd Reitan)
# Adding NORWEGIAN ENERGY COMPANY ASA(Odd Reitan)
# Adding POLARIS MEDIA ASA(Odd Reitan)
# Adding HELTHJEM NETTHANDEL AS(Odd Reitan)
# Adding FAKTISK.NO AS(Odd Reitan)
# Adding TRØNDER-AVISA AS(Odd Reitan)
# Adding FJELLTEATERET I VERA AS(Odd Reitan)
# Adding LEVANGER-AVISA AS(Odd Reitan)
# Adding MEDIEHUSET INNHERRED AS(Odd Reitan)
# Adding VEDDRAR AS(Odd Reitan)
# Adding TOUR DE TOMTVATNET AS(Odd Reitan)
# Adding TRØNDER-DISTRIBUSJON AS(Odd Reitan)
# Adding NORSK TELEGRAMBYRÅ AS(Odd Reitan)
# Adding INFLOW MEDIA AS(Odd Reitan)
# Adding INFLOW MEDIA NORWAY AS(Odd Reitan)
# Adding 24SEVENSOCIAL AS(Odd Reitan)
# Adding AQUALISBRAEMAR LOC ASA(Odd Reitan)
# Adding GRIEG SEAFOOD ASA(Odd Reitan)
# Adding THE SEAFOOD INNOVATION CLUSTER AS(Odd Reitan)
# Adding OCEAN INNOVATION NORWEGIAN CATAPULT AS(Odd Reitan)
# Adding FINNØY NÆRINGSPARK AS(Odd Reitan)
# Adding TEAL AS(Odd Reitan)
# Adding ROGALAND HAVBRUKSPARK AS(Odd Reitan)
# Adding RYFYLKE LIVSGNIST AS(Odd Reitan)
# Adding BJERKREIM NÆRINGSHAGE AS(Odd Reitan)
# Adding BIOENERGI FINNØY AS(Odd Reitan)
# Adding MAGSEIS FAIRFIELD ASA(Odd Reitan)
# Adding PEXIP HOLDING ASA(Odd Reitan)
# Adding PEXIP AS(Odd Reitan)
# Adding AGILYX AS(Odd Reitan)
# Adding AKER CARBON CAPTURE ASA(Odd Reitan)
# Adding AKER CARBON CAPTURE NORWAY AS(Odd Reitan)
# Adding AUSTEVOLL SEAFOOD ASA(Odd Reitan)
# Adding PELAGIA HOLDING AS(Odd Reitan)
# Adding PELAGIA AS(Odd Reitan)
# Adding HORDAFOR AS(Odd Reitan)
# Adding NORTH CAPELIN HONNINGSVÅG AS(Odd Reitan)
# Adding NORTH CAPE FISH HANDLING AS(Odd Reitan)
# Adding NOUMAMI AS(Odd Reitan)
# Adding KALVØYA UTVIKLING AS(Odd Reitan)
# Adding POLARSIRKELEN LUFTHAVNUTVIKLING AS(Odd Reitan)
# Adding SMØLAGRUPPEN AS(Odd Reitan)
# Adding NORDMØRE FISKEBÅT AS(Odd Reitan)
# Adding YTRE SUNNFJORD HOLDING AS(Odd Reitan)
# Adding FIRDAVEGEN 1 AS(Odd Reitan)
# Adding NORKVEITE AS(Odd Reitan)
# Adding MÅLØY VEKST FIBER AS(Odd Reitan)
# Adding TRÆNA FISKER AS(Odd Reitan)
# Adding ÅLESUND STORHALL AS(Odd Reitan)
# Adding ÅLESUND STADION AS(Odd Reitan)
# Adding FISKERINÆRINGENS INNKJØPSSELSKAP AS(Odd Reitan)
# Adding BR BIRKELAND AS(Odd Reitan)
# Adding BR BIRKELAND DRIFT AS(Odd Reitan)
# Adding BK FISK HOLDING AS(Odd Reitan)
# Adding BK FISK AS(Odd Reitan)
# Adding MARIN IT AS(Odd Reitan)
# Adding EURO-TERMINAL AS(Odd Reitan)
# Adding NORWEGIAN FINANS HOLDING ASA(Odd Reitan)
# Adding AKASTOR ASA(Odd Reitan)
# Adding VIKING FOTBALL AS(Odd Reitan)
# Adding VIKINGKLINIKKEN AS(Odd Reitan)
# Adding FLYT SOLA AS(Odd Reitan)
# Adding SULDALSPOSTEN AS(Odd Reitan)
# Adding LOKALAVISSAMKJØRINGA LANDET RUNDT AS(Odd Reitan)
# Adding SULDAL VEKST AS(Odd Reitan)
# Adding JØRPELAND HANDELSFORENING AS(Odd Reitan)
# Adding COLOMBIA KAPITAL AS(Odd Reitan)
# Adding BLUE PLANET AS(Odd Reitan)
# Adding BLUE FRIDAY AS(Odd Reitan)
# Adding BLUE FARM AS(Odd Reitan)
# Adding ENTRA ASA(Odd Reitan)
# Adding HINNA PARK EIENDOM AS(Odd Reitan)
# Adding HINNA PARK AS(Odd Reitan)
# Adding HINNA PARK LOGISTIKK AS(Odd Reitan)
# Adding ORMEN LANGE AS(Odd Reitan)
# Adding OSEBERG NÆRING AS(Odd Reitan)
# Adding HINNA PARK UTVIKLING AS(Odd Reitan)
# Adding FJORDPIREN AS(Odd Reitan)
# Adding HP STADIONBLOKKEN C AS(Odd Reitan)
# Adding TROLL NÆRING AS(Odd Reitan)
# Adding ENTRA OPF UTVIKLING AS(Odd Reitan)
# Adding ENTRA OPF UTVIKLING HOLDING AS(Odd Reitan)
# Adding LARS HILLES GATE 30 HOLDING AS(Odd Reitan)
# Adding LARS HILLES GATE 30 AS(Odd Reitan)
# Adding ALLEHELGENS GATE 6 HOLDING AS(Odd Reitan)
# Adding ALLEHELGENS GATE 6 AS(Odd Reitan)
# Adding HINNA PARK FACILITY MANAGEMENT AS(Odd Reitan)
# Adding ULLANDHAUG ENERGI AS(Odd Reitan)
# Adding OSLO S UTVIKLING AS(Odd Reitan)
# Adding BJØRVIKA UTVIKLING AS(Odd Reitan)
# Adding BJØRVIKA INFRASTRUKTUR AS(Odd Reitan)
# Adding H2O EIENDOM AS(Odd Reitan)
# Adding HINNA PARK UTVIKLING AS(Odd Reitan)
# Adding OSLO KONTOREIENDOM III AS(Odd Reitan)
# Adding ØKERNVEIEN 9 AS(Odd Reitan)
# Adding CKG INVEST AS(Odd Reitan)
# Adding DBC ALTERNATIVT INVESTERINGSFOND AS(Odd Reitan)
# Adding DBC EIENDOMSSELSKAP AS(Odd Reitan)
# Adding DRAMMEN STASJON KONTOR AS(Odd Reitan)
# Adding HELSFYR KONTORINVEST III AS(Odd Reitan)
# Adding HELSFYR KONTORHOLDING III B AS(Odd Reitan)
# Adding HELSFYR KONTORHOLDING III AS(Odd Reitan)
# Adding GRENSESVINGEN 2-18 AS(Odd Reitan)
# Adding HELSFYR KONTORINVEST AS(Odd Reitan)
# Adding HELSFYR KONTORHOLDING AS(Odd Reitan)
# Adding FYRSTIKKALLÉEN 1 AS(Odd Reitan)
# Adding TELEGRAFEN INVEST AS(Odd Reitan)
# Adding TELEGRAFEN HOLDING AS(Odd Reitan)
# Adding K21 HOLDING AS(Odd Reitan)
# Adding K21 SUB-HOLDING AS(Odd Reitan)
# Adding LYSAKER PARK INVEST II AS(Odd Reitan)
# Adding LYSAKER PARK HOLDING AS(Odd Reitan)
# Adding LYSAKER PARK AS(Odd Reitan)
# Adding LYSAKER PARK EIENDOM AS(Odd Reitan)
# Adding STOREBRAND ASA(Odd Reitan)
# Adding STOREBRAND HELSEFORSIKRING AS(Odd Reitan)
# Adding AS VÆRDALSBRUKET(Odd Reitan)
# Adding GRANFOSSEN AS(Odd Reitan)
# Adding INNTRE HOLDING AS(Odd Reitan)
# Adding KJELDSTAD TRELAST AS(Odd Reitan)
# Adding GAULA SENTER AS(Odd Reitan)
# Adding INNTRE KJELDSTAD AS(Odd Reitan)
# Adding TRANSPORTSELSKAPET NORD AS(Odd Reitan)
# Adding INNTRE EIENDOM AS(Odd Reitan)
# Adding GJENSIDIGE FORSIKRING ASA(Odd Reitan)
# Adding OSLO AREAL AS(Odd Reitan)
# Adding DRAMMENSVEIEN 131 AS(Odd Reitan)
# Adding NEDRE VOLLGATE 11 AS(Odd Reitan)
# Adding SCHWEIGAARDSGATE 6-14 AS(Odd Reitan)
# Adding GALLERI OSLO INVEST AS(Odd Reitan)
# Adding STRANDVEIEN 10 AS(Odd Reitan)
# Adding OSLO AREAL DELTAKER AS(Odd Reitan)
# Adding KARENSLYST ALLÉ 8A OG B AS(Odd Reitan)
# Adding PILESTREDET 33 AS(Odd Reitan)
# Adding GRENSEVEIEN 78B AS(Odd Reitan)
# Adding SØRKEDALSVEIEN 6 AS(Odd Reitan)
# Adding KANALPIREN AS(Odd Reitan)
# Adding CHRISTIAN KROHGS GATE 2 AS(Odd Reitan)
# Adding VESTFJORDGATEN 4 AS(Odd Reitan)
# Adding STRANDVEIEN 4-8 AS(Odd Reitan)
# Adding GRENSESVINGEN 7 EIENDOM AS(Odd Reitan)
# Adding LØKKETANGEN 2-14B AS(Odd Reitan)
# Adding AS STORGATEN 51(Odd Reitan)
# Adding TORDENSKIOLDSGATE 6 AS(Odd Reitan)
# Adding TULLINSGATE 2 EIENDOM AS(Odd Reitan)
# Adding KARENSLYST ALLE 7 AS(Odd Reitan)
# Adding OVERHALLA SERVICEBYGG AS(Odd Reitan)
# Adding FJORD INVEST AS(Odd Reitan)
# Adding LANDBRUKETS EIGEDOMSSELSKAP AS(Odd Reitan)
# Adding MIDVEST I AS(Odd Reitan)
# Adding BRATTVAAG ELECTRO AS(Odd Reitan)
# Adding MØREAKSEN AS(Odd Reitan)
# Adding INPOWER INVEST AS(Odd Reitan)
# Adding NAMDAL RESSURS AS(Odd Reitan)
# Adding NORAX TYNSET AS(Odd Reitan)
# Adding ENTEC GROUP AS(Odd Reitan)
# Adding BRIMER SERVITECH AS(Odd Reitan)
# Adding ROBOTEK AS(Odd Reitan)
# Adding EVOTEC AS(Odd Reitan)
# Adding SECTOR ASSET MANAGEMENT AS(Odd Reitan)
# Adding FB2 INVEST AS(Odd Reitan)
# Adding CONVARGANZIA AS(Odd Reitan)
# Adding CONVERGENCE AS(Odd Reitan)
# Adding SECTOR THETA AS(Odd Reitan)
# Adding DUVI AS(Odd Reitan)
# Adding PENSJONSKONTOREGISTERET AS(Odd Reitan)
# Adding SECTOR GAMMA AS(Odd Reitan)
# Adding INCENTIVE AS(Odd Reitan)
# Adding MIMIRO HOLDING AS(Odd Reitan)
# Adding MIMIRO AS(Odd Reitan)
# Adding LÆRDAL ENERGI AS(Odd Reitan)
# Adding SEV AS(Odd Reitan)
# Adding KVEMMA KRAFT AS(Odd Reitan)
# Adding LÆRDAL OG AURLAND GRØNNKRAFT AS(Odd Reitan)
# Adding KRAFTRIKET AS(Odd Reitan)
# Adding NORE KRAFTOMSETNING AS(Odd Reitan)
# Adding YVE AS(Odd Reitan)
# Adding SOGNENETT AS(Odd Reitan)
# Adding ATB-NETT AS(Odd Reitan)
# Adding SEIS AS(Odd Reitan)
# Adding NETTALLIANSEN AS(Odd Reitan)
# Adding T:LAB AS(Odd Reitan)
# Adding T:LAB CAPITAL AS(Odd Reitan)
# Adding ONDEGO AS(Odd Reitan)
# Adding BLUEGROVE AS(Odd Reitan)
# Adding BAG'IN AS(Odd Reitan)
# Adding PAYREST NORGE AS(Odd Reitan)
# Adding ARCTIC FEED INGREDIENTS AS(Odd Reitan)
# Adding SVENN AS(Odd Reitan)
# Adding BOLDBOOKS AS(Odd Reitan)
# Adding TIDLIGFASEFONDET AS(Odd Reitan)
# Adding MUBA AS(Odd Reitan)
# Adding BANDWAGON AS(Odd Reitan)
# Adding CARBON CONCEPTS AS(Odd Reitan)
# Adding SUBMERGED AS(Odd Reitan)
# Adding CAPEESH AS(Odd Reitan)
# Adding ASSITECH AS(Odd Reitan)
# Adding RETYRE AS(Odd Reitan)
# Adding SAFEGRIP AS(Odd Reitan)
# Adding NAVIAQ AS(Odd Reitan)
# Adding VEPAK AS(Odd Reitan)
# Adding BLÅFJELL LIERNE AS(Odd Reitan)
# Adding BLÅFJELL DRIFT AS(Odd Reitan)
# Adding NORINNOVA AS(Odd Reitan)
# Adding CALLMESMART AS(Odd Reitan)
# Adding NORINNOVA NARVIK AS(Odd Reitan)
# Adding GLOBESAR AS(Odd Reitan)
# Adding LIVERPASS AS(Odd Reitan)
# Adding UFORMIA AS(Odd Reitan)
# Adding 3DVERKET AS(Odd Reitan)
# Adding PAZZING AS(Odd Reitan)
# Adding CHIP NANOIMAGING AS(Odd Reitan)
# Adding WINDTECH AS(Odd Reitan)
# Adding TUN MEDIA AS(Odd Reitan)
# Adding AS NATIONEN(Odd Reitan)
# Adding KLOSSER INNOVASJON AS(Odd Reitan)
# Adding CLOUDBERRY CLEAN ENERGY ASA(Odd Reitan)
# Adding FORTE ENERGY NORWAY AS(Odd Reitan)
# Adding ESPEELVI KRAFT AS(Odd Reitan)
# Adding CLOUDBERRY DEVELOP AS(Odd Reitan)
# Adding FINSE KRAFTVERK AS(Odd Reitan)
# Adding SKIPARVIK KRAFTVERK AS(Odd Reitan)
# Adding LERØY BULANDET AS(Odd Reitan)
# Adding SVS MELHUSET AS(Odd Reitan)
# Adding LUSTER ENERGIVERK AS(Odd Reitan)
# Adding LUSTER SMÅKRAFT AS(Odd Reitan)
# Adding SAGE KRAFTVERK AS(Odd Reitan)
# Adding SOGNEKRAFT MOR AS(Odd Reitan)
# Adding SOGNEKRAFT AS(Odd Reitan)
# Adding LEIKANGER KRAFT AS(Odd Reitan)
# Adding NYDALSELVA KRAFT AS(Odd Reitan)
# Adding FJORD ENERGI AS(Odd Reitan)
# Adding NORDFJORDBRUA AS(Odd Reitan)
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# src\pymssql\_pymssql.pyx in pymssql._pymssql.Cursor.execute()
#
# src\pymssql\_mssql.pyx in pymssql._mssql.MSSQLConnection.execute_query()
#
# src\pymssql\_mssql.pyx in pymssql._mssql.MSSQLConnection.execute_query()
#
# src\pymssql\_mssql.pyx in pymssql._mssql.MSSQLConnection.format_and_run_query()
#
# src\pymssql\_mssql.pyx in pymssql._mssql.check_cancel_and_raise()
#
# src\pymssql\_mssql.pyx in pymssql._mssql.raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (2628, b"String or binary data would be truncated in table 'research.dbo.OID_400', column 'owner_path'. Truncated value: 'Odd Reitan/915990487/912609987/914526647/883409442/977370337/983415652/983415660/874537152/917114684'.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n")
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-3fd8cc5e0c99> in <module>
#       4     if (k>=0):# and (orgid in [811176702]):
#       5         print ( 'Appending %s ' %(name,),)
# ----> 6         bf.AppendData(name,conn,crsr,sqlstr,driver)
#       7         print ( ' done')
#       8     k+=1
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in AppendData(name, conn, crsr, sqlstr, driver)
#      98                 owner_path=[]
#      99                 perc_path=[]
# --> 100 		added.append(get_company(driver,oid,owner_path,perc_path,conn,crsr,
#     101                                                                  sqlstr,name,c_name,ownership=(owned_by, owning, desc)
#     102 								 )
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     184         perc_path.append(perc)
#     185         for name,stocks,perc,oid,firm in owning:
# --> 186                 get_company(driver,oid,owner_path,perc_path,conn,crsr,sqlstr,owner_name,name,perc)
#     187
#     188         return True
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in get_company(driver, oid, owner_path, perc_path, conn, crsr, sqlstr, owner_name, comp_name, perc, ownership)
#     165         a=0
#     166
# --> 167 	add_to_db(crsr, conn, sqlstr,
#     168 			  (owner_name,
#     169                            desc['Selskapsnavn'],
#
# B:\Div\Presse\Div saker - grunnlag\Ulikhet\python\billionair_fetch.py in add_to_db(crsr, conn, sqlstr, data, oid, name)
#     277         if exist(crsr, oid, name):
#     278                 return
# --> 279         crsr.execute(sqlstr,tuple(data))
#     280         conn.commit()
#     281
#
# src\pymssql\_pymssql.pyx in pymssql._pymssql.Cursor.execute()
#
# OperationalError: (2628, b"String or binary data would be truncated in table 'research.dbo.OID_400', column 'owner_path'. Truncated value: 'Odd Reitan/915990487/912609987/914526647/883409442/977370337/983415652/983415660/874537152/917114684'.DB-Lib error message 20018, severity 16:\nGeneral SQL Server error: Check messages from the SQL Server\n")

# %%
DB.CreateIndex(conn,crsr,tbl,db)

# %%
# Out:
# 300
